# %% [raw]
# Лабораторна робота №8.
# Тема.Модулі, пакети та pip
# Мета: навчитися імпортувати, користуватися, створювати модулі та пакети. Навчитися користуватися “сирною крамницею” PyPi та менеджером пакетів pip
#
#                                                     Хід роботи

# %%
# Завдання 1

import module

def main():
    """Основна функція."""
    name = input("Enter your name: ")
    print(module.greeting(name))

    # Використання функції додавання чисел
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print(f"The sum of {a} and {b} is: {module.add_numbers(a, b)}")

if __name__ == "__main__":
    main()
# Завдання 2

from extra.math_tools import multiply, divide
from extra.string_tools import reverse_string, capitalize_string

def main():
    """Основна функція."""
    # Демонстрація математичних функцій
    print("Math tools demo:")
    print(f"5 * 3 = {multiply(5, 3)}")
    print(f"10 / 2 = {divide(10, 2)}")
    print(f"10 / 0 = {divide(10, 0)}")

    # Демонстрація роботи з рядками
    print("\nString tools demo:")
    print(f"Reverse of 'hello' is: {reverse_string('hello')}")
    print(f"Capitalized 'world' is: {capitalize_string('world')}")

if __name__ == "__main__":
    main()

# %% [raw]
# Контрольні запитання
# 1. Заборонити запуск модуля як скрипта**
#
# Щоб заборонити запускати модуль як скрипт, можна додати перевірку, яка викличе помилку, якщо модуль виконується напряму:
#
# ```python
# if __name__ == "__main__":
#     raise RuntimeError("Цей модуль не можна запускати напряму.")
# ```
# ---
# 2. Налаштування пошуку модулів у каталозі `D:\Python\Project\Modules`
#
# Для додавання каталогу до списку пошуку модулів Python (`sys.path`), використовуйте наступний код:
#
# ```python
# import sys
#
# Додаємо каталог до списку пошуку модулів
# sys.path.append(r"D:\Python\Project\Modules")
#
# print("Каталог успішно додано до sys.path")
# ```
#
# ---
# 3.Використання сутностей з `mymodule`**
#
# Для роботи з структурою:
#
# ```
# abc/
# ├── def/
# │   └── mymodule.py
# ```
#
# і можливістю використовувати всі сутності з модуля `mymodule`, додайте до файлу `mymodule.py` необхідний код, наприклад:
#
# **Файл `mymodule.py`:**
# ```python
# def example_function():
#     return "Це функція з mymodule"
#
# class ExampleClass:
#     def greet(self):
#         return "Привіт із ExampleClass"
# ```
#
# Щоб імпортувати всі сутності з модуля, у головному файлі напишіть:
#
# ```python
# from abc.def.mymodule import *
#
# # Використання функції та класу
# print(example_function())  # Виклик функції
# obj = ExampleClass()
# print(obj.greet())         # Виклик методу класу
# ```
