# %% [raw]
# Лабораторна робота 2
# Тема.	Функція print()
# Мета: навчитися писати та запускати найпростіші програми на Python з використанням функції print().
#
#                                                     Хід роботи

# %%
# task 1
print("Programming***Essentials***in...", end="")
print("Python\n")
# task 2
print("    *")
print("   * *")
print("  *   *")
print(" *     *")
print("***   ***")
print("  *   *")
print("  *   *")
print("  *****\n")
# task 3
print("I'm student\n")
# task 4
print("\"I\'m\"\n\"learning\"\n\"\"\"Python\"\"\"\n")
# task 5
decimal_500 = int("500", 8)
print(decimal_500)
# task 6
decimal_777 = int("777", 16)
print(decimal_777)

# %% [raw]
#                                                     Контрольні запитання
# Ієрархія операторів в Python:
# Ієрархія операторів в Python визначає порядок виконання операцій у виразах. Оператори з вищим пріоритетом виконуються першими. Ось загальна ієрархія операторів (від найвищого до найнижчого):
# Круглі дужки ()
#
# Операції в дужках виконуються першими.
# Оператори піднесення до ступеня **
#
# Наприклад: 2 ** 3 (це буде рівно 8).
# Оператори множення, ділення, ціле ділення та залишку: *, /, //, %
#
# Множення: *
# Ділення: /
# Ціле ділення: //
# Залишок від ділення: %
# Оператори додавання і віднімання: +, -
#
# Додавання: +
# Віднімання: -
# Оператори порівняння: ==, !=, <, <=, >, >=
#
# Порівняння на рівність: ==
# Порівняння на нерівність: !=
# Більше, менше, більше або рівне, менше або рівне: <, >, <=, >=
# Логічні оператори: and, or, not
#
# and (логічне І)
# or (логічне АБО)
# not (логічне НЕ)
# Оператори присвоєння: =, +=, -=, *=, /=, %=, **=, //=
#
# Наприклад: a += 5 означає a = a + 5.
# Оператори ідентичності: is, is not
#
# is перевіряє, чи два об'єкти є одним і тим самим.
# is not перевіряє, чи два об'єкти не є одним і тим самим.
# Оператори членства: in, not in
#
# in перевіряє, чи елемент знаходиться в колекції.
# not in перевіряє, чи елемент не знаходиться в колекції.
#
# Обчислення виразу на Python:
# Наприклад, для обчислення виразу:
# (3+5)∗2∗∗3/4−7(3 + 5) * 2 ** 3 / 4 - 7
# Це можна записати на Python так:
# result = (3 + 5) * 2 ** 3 / 4 - 7
# print(result)
#
# У цьому виразі:
# Спочатку виконується піднесення до ступеня 2 ** 3 (8).
# Потім виконується множення: (3 + 5) * 8 (8 * 8 = 64).
# Далі виконується ділення: 64 / 4 (16.0).
# В кінці віднімається 7: 16.0 - 7 (результат 9.0).
#
# Що робить escape-символ при виведенні на екран функцією print()?
# Escape-символи в Python використовуються для введення спеціальних символів у рядок. Вони починаються з зворотного слешу \. Ось кілька прикладів escape-символів:
# \n — новий рядок (перехід на новий рядок):
#
#  print("Hello\nWorld")
#  Виведе:
#
#  Hello
# World
#
# \t — табуляція (відступ):
#
#  print("Hello\tWorld")
#  Виведе:
#
#  Hello   World
#
# \\ — зворотний слеш:
#
#  print("This is a backslash: \\")
#  Виведе:
#
#  This is a backslash: \
#
# \' — одинарна лапка в рядку:
#
#  print('It\'s a nice day')
#  Виведе:
#
#  It's a nice day
#
# \" — подвійна лапка в рядку:
#
#  print("She said \"Hello!\"")
#  Виведе:
#
#  She said "Hello!"
#
# Таким чином, escape-символи дозволяють вставляти спеціальні символи в текст, які інакше не могли б бути безпосередньо включені в рядок, такі як новий рядок, табуляція або лапки.
